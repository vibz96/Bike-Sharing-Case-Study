# %%
# Importing the libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

import sklearn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

import statsmodels.api as sm

from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.metrics import r2_score

# %%
#Importing Data set
bike_df = pd.read_csv('/content/day.csv')

# %%
bike_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
bike_df.shape
# Out:
# (730, 16)

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
bike_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %% [markdown]
# There are total of 730 rows and 16 columns in dataset

# %% [markdown]
# ##Checking for Null values in dataset

# %%
bike_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# Lets check for duplicates in dataset

# %%
#Making new dataframe for duplicates from original dataset
bike_df_dups = bike_df
bike_df_dups.drop_duplicates(inplace=True)

# %%
bike_df_dups.shape
# Out:
# (730, 16)

# %% [markdown]
# *   As we can see there are no duplicates available in dataset

# %% [markdown]
# ##Cleaning dataset
#
#
# *   Removing unwanted column from dataset.

# %%
bike_df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# *   dropping instant column from dataset becuase we already have index column.
# *   dropping dteday column as that not required for analysis.
# *   dropping casual and registered column as we already have cnt column which is addition of there both column

# %%
bike_pred_df = bike_df[['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum'
                     , 'windspeed', 'cnt']]
bike_pred_df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %% [markdown]
# ##Creating dummy variable

# %%
bike_pred_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 74.1 KB

# %%
# Converting the above mentioned columns into categories

bike_pred_df.season = bike_pred_df.season.astype('category')
bike_pred_df.weekday = bike_pred_df.weekday.astype('category')
bike_pred_df.mnth = bike_pred_df.mnth.astype('category')
bike_pred_df.weathersit = bike_pred_df.weathersit.astype('category')
bike_pred_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(4)
# memory usage: 55.2 KB

# %%
# Creating dummies of the converted variables and dropping the first variable as (n-1)

bike_pred_df = pd.get_dummies(bike_pred_df, drop_first=True)
bike_pred_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   workingday    730 non-null    int64
#  3   temp          730 non-null    float64
#  4   atemp         730 non-null    float64
#  5   hum           730 non-null    float64
#  6   windspeed     730 non-null    float64
#  7   cnt           730 non-null    int64
#  8   season_2      730 non-null    uint8
#  9   season_3      730 non-null    uint8
#  10  season_4      730 non-null    uint8
#  11  mnth_2        730 non-null    uint8
#  12  mnth_3        730 non-null    uint8
#  13  mnth_4        730 non-null    uint8
#  14  mnth_5        730 non-null    uint8
#  15  mnth_6        730 non-null    uint8
#  16  mnth_7        730 non-null    uint8
#  17  mnth_8        730 non-null    uint8
# ...

# %% [markdown]
# ##Splitting data into Test/Train data

# %%
#dividing dataset in 70:30
bike_df_train, bike_df_test  = train_test_split(bike_pred_df,train_size=0.7,test_size=0.3,random_state=True)

# %%
bike_df_train.shape
# Out:
# (510, 30)

# %%
bike_df_test.shape
# Out:
# (219, 30)

# %% [markdown]
# #EDA on Dataset

# %%
bike_pred_df.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'cnt', 'season_2', 'season_3', 'season_4', 'mnth_2', 'mnth_3', 'mnth_4',
#        'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11',
#        'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6', 'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
bike_pred_num = bike_pred_df[['temp','atemp','hum','windspeed','cnt']]
sns.pairplot(bike_pred_num)
plt.show()

# %% [markdown]
# From above we can conclude that there is relation between atemp, temp and cnt

# %% [markdown]
# **Making boxplots for the categorical variables.**

# %%
plt.figure(figsize=(26,10))

plt.subplot(2,3,1)
sns.boxplot(x='season', y='cnt', data=bike_df)

plt.subplot(2,3,2)
sns.boxplot(x='mnth', y='cnt', data=bike_df)

plt.subplot(2,3,3)
sns.boxplot(x='weathersit', y='cnt', data=bike_df)

plt.subplot(2,3,4)
sns.boxplot(x='weekday', y='cnt', data=bike_df)

plt.subplot(2,3,5)
sns.boxplot(x='holiday', y='cnt', data=bike_df)

plt.subplot(2,3,6)
sns.boxplot(x='workingday', y='cnt', data=bike_df)

plt.show()

# %%
# Checking for the correlation among different variables with the help of heatmap.

plt.figure(figsize=(25,18))

sns.heatmap(bike_pred_df.corr(), annot=True, cmap='YlGnBu')

plt.show()

# %% [markdown]
# From above we can conclude that there are some variable have high collinearity

# %%
scaler = MinMaxScaler()

# %%
bike_df_train.head()
# Out:
#      yr  holiday  workingday       temp    atemp      hum  windspeed   cnt  \
# 589   1        0           1  29.554153  33.1127  54.5417   9.126204  6883
# 135   0        0           1  23.677500  27.5256  78.7917   8.500357  3958
# 626   1        0           1  22.652500  27.0202  53.6667  14.416725  7591
# 554   1        0           1  29.144153  32.7027  68.3333  12.125325  6569
# 311   0        0           1  16.741653  20.6123  72.1667   4.625513  4205
#
#      season_2  season_3  ...  mnth_11  mnth_12  weekday_1  weekday_2  \
# 589         0         1  ...        0        0          1          0
# 135         1         0  ...        0        0          1          0
# 626         0         1  ...        0        0          0          0
# 554         0         1  ...        0        0          1          0
# 311         0         0  ...        1        0          0          1
#
#      weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  weathersit_3
# ...

# %%
# Creating a list of numeric variables

num_vars = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']

# %%
# Using the scaler() function in the numeric variables

bike_df_train[num_vars] = scaler.fit_transform(bike_df_train[num_vars])

# %%
bike_df_train.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 589   1        0           1  0.837559  0.804151  0.405453   0.271536
# 135   0        0           1  0.656134  0.650070  0.743040   0.249252
# 626   1        0           1  0.624490  0.636133  0.393272   0.459915
# 554   1        0           1  0.824902  0.792844  0.597447   0.378326
# 311   0        0           1  0.442008  0.459416  0.650812   0.111281
#
#           cnt  season_2  season_3  ...  mnth_11  mnth_12  weekday_1  \
# 589  0.789347         0         1  ...        0        0          1
# 135  0.452830         1         0  ...        0        0          1
# 626  0.870801         0         1  ...        0        0          0
# 554  0.753221         0         1  ...        0        0          1
# 311  0.481247         0         0  ...        1        0          0
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  \
# ...

# %%
bike_df_train.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.505882    0.031373    0.682353    0.565908    0.558218    0.525948
# std      0.500456    0.174494    0.466018    0.226756    0.219143    0.194221
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.373710    0.381919    0.379602
# 50%      1.000000    0.000000    1.000000    0.583879    0.586935    0.523202
# 75%      1.000000    0.000000    1.000000    0.759768    0.735616    0.668503
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed         cnt    season_2    season_3  ...     mnth_11  \
# count  510.000000  510.000000  510.000000  510.000000  ...  510.000000
# mean     0.400742    0.526245    0.264706    0.266667  ...    0.098039
# ...

# %% [markdown]
# ##Building linear model

# %%
y_train = bike_df_train.pop('cnt')
X_train = bike_df_train

# %%
X_train.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 589   1        0           1  0.837559  0.804151  0.405453   0.271536
# 135   0        0           1  0.656134  0.650070  0.743040   0.249252
# 626   1        0           1  0.624490  0.636133  0.393272   0.459915
# 554   1        0           1  0.824902  0.792844  0.597447   0.378326
# 311   0        0           1  0.442008  0.459416  0.650812   0.111281
#
#      season_2  season_3  season_4  ...  mnth_11  mnth_12  weekday_1  \
# 589         0         1         0  ...        0        0          1
# 135         1         0         0  ...        0        0          1
# 626         0         1         0  ...        0        0          0
# 554         0         1         0  ...        0        0          1
# 311         0         0         1  ...        1        0          0
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  \
# ...

# %% [markdown]
# ##Recursive Feature Elimination (RFE)

# %%
# Calling the LinearRegression function from the SciKit Learn

lm = LinearRegression()
lm.fit(X_train, y_train)

# Running the RFE function on the Target var. & Indep. var.

rfe = RFE(lm,step=15)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', False, 2),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_2', True, 1),
#  ('season_3', False, 2),
#  ('season_4', True, 1),
#  ('mnth_2', False, 2),
#  ('mnth_3', False, 2),
#  ('mnth_4', False, 2),
#  ('mnth_5', False, 2),
#  ('mnth_6', False, 2),
#  ('mnth_7', False, 2),
#  ('mnth_8', False, 2),
#  ('mnth_9', False, 2),
#  ('mnth_10', False, 2),
#  ('mnth_11', False, 2),
#  ('mnth_12', False, 2),
#  ('weekday_1', True, 1),
#  ('weekday_2', True, 1),
#  ('weekday_3', True, 1),
#  ('weekday_4', True, 1),
#  ('weekday_5', True, 1),
#  ('weekday_6', False, 2),
#  ('weathersit_2', False, 2),
#  ('weathersit_3', True, 1)]

# %%
# Storing the 'True' columns from the rfe.support_ list

col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'season_2',
#        'season_4', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weathersit_3'],
#       dtype='object')

# %%
# Having a look to the columns that haven't been taken by the rfe.support_

X_train.columns[~rfe.support_]
# Out:
# Index(['atemp', 'season_3', 'mnth_2', 'mnth_3', 'mnth_4', 'mnth_5', 'mnth_6',
#        'mnth_7', 'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11', 'mnth_12',
#        'weekday_6', 'weathersit_2'],
#       dtype='object')

# %%
# Creating X_test df with the RFE selected vars.

X_train_rfe = X_train[col]

# %% [markdown]
# ##Linear Model Using stats model
#
# #1.   Model-1

# %%
X_train_rfe.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed  season_2  \
# 589   1        0           1  0.837559  0.405453   0.271536         0
# 135   0        0           1  0.656134  0.743040   0.249252         1
# 626   1        0           1  0.624490  0.393272   0.459915         0
# 554   1        0           1  0.824902  0.597447   0.378326         0
# 311   0        0           1  0.442008  0.650812   0.111281         0
#
#      season_4  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# 589         0          1          0          0          0          0
# 135         0          1          0          0          0          0
# 626         0          0          0          1          0          0
# 554         0          1          0          0          0          0
# 311         1          0          1          0          0          0
#
#      weathersit_3
# 589             0
# 135             0
# 626             0
# 554             0
# 311             0

# %%
# VIF Check

# Creating a dataframe that'll contain the names of all the feature variable & their respective VIF's

vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#         Features   VIF
# 1        holiday   inf
# 2     workingday   inf
# 8      weekday_1   inf
# 9      weekday_2   inf
# 10     weekday_3   inf
# 11     weekday_4   inf
# 12     weekday_5   inf
# 4            hum  7.21
# 3           temp  6.47
# 5      windspeed  3.81
# 0             yr  1.97
# 7       season_4  1.60
# 6       season_2  1.56
# 13  weathersit_3  1.21

# %%
# Adding a constant

X_train_sm1 = sm.add_constant(X_train_rfe)

# Creating a first fitted model

lr1 = sm.OLS(y_train, X_train_sm1)

# %%
# Using the .fit() function

lr1_model = lr1.fit()

# Checking the parameters

lr1_model.params
# Out:
# const           0.191433
# yr              0.229230
# holiday        -0.060510
# workingday      0.011152
# temp            0.597841
# hum            -0.184878
# windspeed      -0.166979
# season_2        0.073310
# season_4        0.128825
# weekday_1      -0.016471
# weekday_2      -0.025279
# weekday_3       0.000946
# weekday_4       0.003819
# weekday_5      -0.012373
# weathersit_3   -0.179819
# dtype: float64

# %%
# Printing the summary

lr1_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     152.3
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          1.06e-163
# Time:                        15:41:08   Log-Likelihood:                 462.12
# No. Observations:                 510   AIC:                            -896.2
# Df Residuals:                     496   BIC:                            -837.0
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #2. model-2

# %%
# Dropping the 'weekday_3' columns because of its high VIF Value and high P value.

X_train_model2 = X_train_rfe.drop(['weekday_3'], axis=1)

# %%
vif = pd.DataFrame()
vif['Features'] = X_train_model2.columns
vif['VIF'] = [variance_inflation_factor(X_train_model2.values, i) for i in range(X_train_model2.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#         Features   VIF
# 4            hum  7.21
# 2     workingday  7.18
# 3           temp  6.47
# 5      windspeed  3.81
# 8      weekday_1  2.22
# 9      weekday_2  2.07
# 10     weekday_4  2.03
# 11     weekday_5  2.03
# 0             yr  1.97
# 7       season_4  1.60
# 6       season_2  1.56
# 1        holiday  1.43
# 12  weathersit_3  1.21

# %%
# Adding a constant

X_train_sm2 = sm.add_constant(X_train_model2)

# Creating a first fitted model

lr2 = sm.OLS(y_train, X_train_sm2)

# %%
# Using the .fit() function

lr2_model = lr2.fit()

# Checking the parameters

lr2_model.params
# Out:
# const           0.191433
# yr              0.229230
# holiday        -0.059565
# workingday      0.012098
# temp            0.597841
# hum            -0.184878
# windspeed      -0.166979
# season_2        0.073310
# season_4        0.128825
# weekday_1      -0.017417
# weekday_2      -0.026225
# weekday_4       0.002873
# weekday_5      -0.013318
# weathersit_3   -0.179819
# dtype: float64

# %%
# Printing the summary

lr2_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     152.3
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          1.06e-163
# Time:                        15:41:08   Log-Likelihood:                 462.12
# No. Observations:                 510   AIC:                            -896.2
# Df Residuals:                     496   BIC:                            -837.0
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# Dropping the 'weekday_4' columns because of its high VIF Value and high P value.

X_train_model3 = X_train_model2.drop(['weekday_4'], axis=1)

# %%
vif = pd.DataFrame()
vif['Features'] = X_train_model3.columns
vif['VIF'] = [variance_inflation_factor(X_train_model3.values, i) for i in range(X_train_model3.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#         Features   VIF
# 4            hum  7.21
# 3           temp  6.46
# 2     workingday  4.61
# 5      windspeed  3.81
# 0             yr  1.97
# 8      weekday_1  1.65
# 7       season_4  1.60
# 6       season_2  1.56
# 9      weekday_2  1.53
# 10     weekday_5  1.51
# 1        holiday  1.30
# 11  weathersit_3  1.20

# %%
# Adding a constant

X_train_sm3 = sm.add_constant(X_train_model3)

# Creating a first fitted model

lr3 = sm.OLS(y_train, X_train_sm3)

# %%
# Using the .fit() function

lr3_model = lr3.fit()

# Checking the parameters

lr3_model.params
# Out:
# const           0.191554
# yr              0.229238
# holiday        -0.058031
# workingday      0.013555
# temp            0.597687
# hum            -0.184968
# windspeed      -0.166977
# season_2        0.073344
# season_4        0.128865
# weekday_1      -0.018881
# weekday_2      -0.027685
# weekday_5      -0.014788
# weathersit_3   -0.180273
# dtype: float64

# %%
lr3_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     165.3
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          8.22e-165
# Time:                        15:41:08   Log-Likelihood:                 462.10
# No. Observations:                 510   AIC:                            -898.2
# Df Residuals:                     497   BIC:                            -843.2
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #3. Model-3

# %%
# Dropping the 'weekday_4' columns because of its high VIF Value and high P value.

X_train_model4 = X_train_model3.drop(['weekday_5'], axis=1)

# %%
vif = pd.DataFrame()
vif['Features'] = X_train_model4.columns
vif['VIF'] = [variance_inflation_factor(X_train_model4.values, i) for i in range(X_train_model4.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#         Features   VIF
# 4            hum  7.21
# 3           temp  6.45
# 5      windspeed  3.81
# 2     workingday  3.79
# 0             yr  1.97
# 7       season_4  1.60
# 6       season_2  1.56
# 8      weekday_1  1.47
# 9      weekday_2  1.36
# 1        holiday  1.27
# 10  weathersit_3  1.18

# %%
# Adding a constant

X_train_sm4 = sm.add_constant(X_train_model4)

# Creating a first fitted model

lr4 = sm.OLS(y_train, X_train_sm4)

# %%
# Using the .fit() function

lr4_model = lr4.fit()

# Checking the parameters

lr4_model.params
# Out:
# const           0.191703
# yr              0.229203
# holiday        -0.062485
# workingday      0.008632
# temp            0.598414
# hum            -0.185556
# windspeed      -0.167803
# season_2        0.073524
# season_4        0.128757
# weekday_1      -0.014026
# weekday_2      -0.022725
# weathersit_3   -0.177018
# dtype: float64

# %%
lr4_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     180.3
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          9.99e-166
# Time:                        15:41:08   Log-Likelihood:                 461.57
# No. Observations:                 510   AIC:                            -899.1
# Df Residuals:                     498   BIC:                            -848.3
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #4. Model-4

# %%
X_train_model5 = X_train_model4.drop(['workingday'], axis=1)

# %%
vif = pd.DataFrame()
vif['Features'] = X_train_model5.columns
vif['VIF'] = [variance_inflation_factor(X_train_model5.values, i) for i in range(X_train_model5.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#        Features   VIF
# 3           hum  6.97
# 2          temp  6.24
# 4     windspeed  3.69
# 0            yr  1.95
# 6      season_4  1.59
# 5      season_2  1.56
# 7     weekday_1  1.34
# 8     weekday_2  1.22
# 9  weathersit_3  1.18
# 1       holiday  1.14

# %%
# Adding a constant

X_train_sm5 = sm.add_constant(X_train_model5)

# Creating a first fitted model

lr5 = sm.OLS(y_train, X_train_sm5)

# %%
# Using the .fit() function

lr5_model = lr5.fit()

# Checking the parameters

lr5_model.params
# Out:
# const           0.196683
# yr              0.229534
# holiday        -0.070054
# temp            0.598922
# hum            -0.185652
# windspeed      -0.168503
# season_2        0.073597
# season_4        0.128578
# weekday_1      -0.010650
# weekday_2      -0.019175
# weathersit_3   -0.175998
# dtype: float64

# %%
lr5_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     198.4
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          9.56e-167
# Time:                        15:41:09   Log-Likelihood:                 461.24
# No. Observations:                 510   AIC:                            -900.5
# Df Residuals:                     499   BIC:                            -853.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #5. Model-5

# %%
X_train_model6 = X_train_model5.drop(['weekday_1'], axis=1)

vif = pd.DataFrame()
vif['Features'] = X_train_model6.columns
vif['VIF'] = [variance_inflation_factor(X_train_model6.values, i) for i in range(X_train_model6.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#        Features   VIF
# 3           hum  6.90
# 2          temp  6.23
# 4     windspeed  3.66
# 0            yr  1.95
# 6      season_4  1.59
# 5      season_2  1.56
# 7     weekday_2  1.19
# 8  weathersit_3  1.18
# 1       holiday  1.04

# %%
# Adding a constant

X_train_sm6 = sm.add_constant(X_train_model6)

# Creating a first fitted model

lr6 = sm.OLS(y_train, X_train_sm6)

# Using the .fit() function

lr6_model = lr6.fit()

# Checking the parameters

lr6_model.params
# Out:
# const           0.196157
# yr              0.229654
# holiday        -0.076436
# temp            0.598734
# hum            -0.186933
# windspeed      -0.169700
# season_2        0.073566
# season_4        0.128802
# weekday_2      -0.017471
# weathersit_3   -0.175202
# dtype: float64

# %%
lr6_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     220.5
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          8.71e-168
# Time:                        15:41:09   Log-Likelihood:                 460.90
# No. Observations:                 510   AIC:                            -901.8
# Df Residuals:                     500   BIC:                            -859.5
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #6. Model-6

# %%
X_train_model7 = X_train_model6.drop(['weekday_2'], axis=1)

vif = pd.DataFrame()
vif['Features'] = X_train_model7.columns
vif['VIF'] = [variance_inflation_factor(X_train_model7.values, i) for i in range(X_train_model7.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#        Features   VIF
# 3           hum  6.89
# 2          temp  6.22
# 4     windspeed  3.62
# 0            yr  1.95
# 6      season_4  1.59
# 5      season_2  1.56
# 7  weathersit_3  1.17
# 1       holiday  1.04

# %%
# Adding a constant

X_train_sm7 = sm.add_constant(X_train_model7)

# Creating a first fitted model

lr7 = sm.OLS(y_train, X_train_sm7)

# Using the .fit() function

lr7_model = lr7.fit()

# Checking the parameters

lr7_model.params
# Out:
# const           0.196057
# yr              0.229671
# holiday        -0.073837
# temp            0.597762
# hum            -0.188075
# windspeed      -0.172380
# season_2        0.072942
# season_4        0.128118
# weathersit_3   -0.172935
# dtype: float64

# %%
lr7_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     247.4
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          1.39e-168
# Time:                        15:41:09   Log-Likelihood:                 459.92
# No. Observations:                 510   AIC:                            -901.8
# Df Residuals:                     501   BIC:                            -863.7
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #7. Model-7

# %%
X_train_model8 = X_train_model7.drop(['hum'], axis=1)

vif = pd.DataFrame()
vif['Features'] = X_train_model8.columns
vif['VIF'] = [variance_inflation_factor(X_train_model8.values, i) for i in range(X_train_model8.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#        Features   VIF
# 2          temp  3.51
# 3     windspeed  3.43
# 0            yr  1.95
# 4      season_2  1.54
# 5      season_4  1.34
# 6  weathersit_3  1.06
# 1       holiday  1.04

# %%
# Adding a constant

X_train_sm8 = sm.add_constant(X_train_model8)

# Creating a first fitted model

lr8 = sm.OLS(y_train, X_train_sm8)

# Using the .fit() function

lr8_model = lr8.fit()

# Checking the parameters

lr8_model.params
# Out:
# const           0.091994
# yr              0.237944
# holiday        -0.069918
# temp            0.576176
# windspeed      -0.124141
# season_2        0.069603
# season_4        0.115836
# weathersit_3   -0.246621
# dtype: float64

# %%
lr8_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.777
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     249.3
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):          6.81e-159
# Time:                        15:41:09   Log-Likelihood:                 434.28
# No. Observations:                 510   AIC:                            -852.6
# Df Residuals:                     502   BIC:                            -818.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# * This model i.e. Model 7, looks good, as there seems to be VERY LOW Multicollinearity between the predictors and the p-values for all the predictors seems to be significant. For now, we will consider this as our final model.
# * There seems a slight P-Value in the 'Holiday' variable but it is well below the P-Value limit i.e. 0.05, therefore it is safe to keep it for further prediction analysis.

# %% [markdown]
# ##Hypothesis Testing:
# **Hypothesis statement states that:**
#
#     **H0 : B1 = B2 = ... = Bn = 0**
#
#     **H1 : Bi != 0**
#
# Here H0 --> Null Hypothesis H1 --> Alternate Hypothesis.
#
# Model coefficient values,
#
#     const           0.091994
#     yr              0.237944
#     holiday        -0.069918
#     temp            0.576176
#     windspeed      -0.124141
#     season_2        0.069603
#     season_4        0.115836
#     weathersit_3   -0.246621
#
# Insight:
# * It is evident from the Model 8 that none of the coefficients are equal to 0, which means **REJECT THE NULL HYPOTHESIS**.
#
# **F-Statistic:**
#
# * F-Statistic is used for overall significance of the model.
#
#       The F-Statistic value: 249.3
#
#       The Prob(F-Statistic) value : 6.81e-159
#
# So, as the P-Value is ~0.000 and from the F-Statistic data we can conclude that our prediction model is significant.
#
# **Equation for the best fit line:**
#
#     cnt = 0.091994 + (yr * 0.237944) + (holiday * (-0.069918)) + (temp * 0.576176) + (windspeed * (-0.124141)) + (season_2 * 0.069603) + (season_4 * 0.115836) + (weathersit_3 * (-0.246621))
#
# **Interpretation of the equation:**
#
#     YR - Coefficient of yr indicates that a unit increase in yr variable, will increase bike hirings by 0.237 values.
#     HOLIDAY - Coefficient of holiday indicates that a unit increase in holiday variable, will decrease the bike hiring by 0.0699 values.
#     TEMP - Coefficient of temp indicates that a unit increase in temp variable, will increase the bike hiring by 0.5761 values.
#     WINDSPEED - Coefficient of the windspeed indicates that a unit increase in windspeed data, will decrease the bike hiring by 0.1241 values.
#     SEASON_2 - The coefficient of season_3 indicates that a unit increase in the season_2, will increase the bike hiring by 0.0696 values.
#     SEASON_4 - tHE coefficient of season_4 indicates a unit increase in the season_4, will increase the bike hiring by 0.1158 values.
#     WEATHERSIT_3 - Coefficient of weathersit_3 indicates that a unit increase in the weathersit_3, will decrease the bike hiring by 0.2466 values.

# %% [markdown]
# ##Model Validation

# %%
y_train_pred = lr8_model.predict(X_train_sm8)

# %%
res = y_train - y_train_pred

# %%
sns.distplot((res), bins=20)
plt.title('Error Terms', fontsize=20)
plt.xlabel('Errors', fontsize=15)

plt.show()

# %% [markdown]
# ###From the above histogram, we could see that the Residuals are normally distributed. Hence our assumption for Linear Regression is valid.

# %%
# VIF Check

# Creating a dataframe that'll contain the names of all the feature variable & their respective VIF's

vif = pd.DataFrame()
vif['Features'] = X_train_model8.columns
vif['VIF'] = [variance_inflation_factor(X_train_model8.values, i) for i in range(X_train_model8.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#        Features   VIF
# 2          temp  3.51
# 3     windspeed  3.43
# 0            yr  1.95
# 4      season_2  1.54
# 5      season_4  1.34
# 6  weathersit_3  1.06
# 1       holiday  1.04

# %% [markdown]
# ###From the VIF calculation we could find that there is no multicollinearity existing between the predictor variables, as all the values are within permissible range of below 5.

# %% [markdown]
# ##Final model prediction

# %%
# Using scaler.transform as we want our Test data to predict learned from the Training data.

num_vars = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']

bike_df_test[num_vars] = scaler.transform(bike_df_test[num_vars])

bike_df_test.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 248   0        0           1  0.608667  0.601379  0.880915   0.767112
# 298   0        0           1  0.537996  0.542977  0.649072   0.301190
# 159   0        0           1  0.948314  0.935594  0.437354   0.304151
# 660   1        0           1  0.613942  0.622206  0.539443   0.172135
# 511   1        0           0  0.798532  0.775430  0.616589   0.459906
#
#           cnt  season_2  season_3  ...  mnth_11  mnth_12  weekday_1  \
# 248  0.309250         0         1  ...        0        0          0
# 298  0.445467         0         0  ...        0        0          0
# 159  0.447883         1         0  ...        0        0          0
# 660  0.856420         0         0  ...        0        0          0
# 511  0.755752         1         0  ...        0        0          0
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  \
# ...

# %%
bike_df_test.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.488584    0.022831    0.684932    0.522428    0.516274    0.505221
# std      0.501015    0.149707    0.465607    0.240519    0.235211    0.207081
# min      0.000000    0.000000    0.000000    0.048429    0.051165   -0.353829
# 25%      0.000000    0.000000    0.000000    0.303278    0.303598    0.350058
# 50%      0.000000    0.000000    1.000000    0.512681    0.521179    0.511021
# 75%      1.000000    0.000000    1.000000    0.746847    0.717542    0.648782
# max      1.000000    1.000000    1.000000    1.015822    1.050480    0.968097
#
#         windspeed         cnt    season_2    season_3  ...     mnth_11  \
# count  219.000000  219.000000  219.000000  219.000000  ...  219.000000
# mean     0.403360    0.493968    0.223744    0.237443  ...    0.045662
# ...

# %%
y_test = bike_df_test.pop('cnt')
X_test = bike_df_test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cnt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 248 to 540
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            219 non-null    int64
#  1   holiday       219 non-null    int64
#  2   workingday    219 non-null    int64
#  3   temp          219 non-null    float64
#  4   atemp         219 non-null    float64
#  5   hum           219 non-null    float64
#  6   windspeed     219 non-null    float64
#  7   season_2      219 non-null    uint8
#  8   season_3      219 non-null    uint8
#  9   season_4      219 non-null    uint8
#  10  mnth_2        219 non-null    uint8
#  11  mnth_3        219 non-null    uint8
#  12  mnth_4        219 non-null    uint8
#  13  mnth_5        219 non-null    uint8
#  14  mnth_6        219 non-null    uint8
#  15  mnth_7        219 non-null    uint8
#  16  mnth_8        219 non-null    uint8
#  17  mnth_9        219 non-null    uint8
# ...

# %%
col_1 = X_train_model8.columns
X_test = X_test[col_1]

# %%
# Adding constant variable to test df

X_test_sm8 = sm.add_constant(X_test)
X_test_sm8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 248 to 540
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   const         219 non-null    float64
#  1   yr            219 non-null    int64
#  2   holiday       219 non-null    int64
#  3   temp          219 non-null    float64
#  4   windspeed     219 non-null    float64
#  5   season_2      219 non-null    uint8
#  6   season_4      219 non-null    uint8
#  7   weathersit_3  219 non-null    uint8
# dtypes: float64(3), int64(2), uint8(3)
# memory usage: 10.9 KB

# %%
# Making Predictions using the final model

y_pred = lr8_model.predict(X_test_sm8)

# %%
# Plotting y_test and y_pred to understand

plt.scatter(y_test, y_pred, alpha=0.5)
plt.title('y_test vs y_pred\n', fontsize=20)
plt.xlabel('y_test', fontsize=15)
plt.ylabel('y_pred', fontsize=15)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7984970457094572

# %%
# Getting the shape of test data

X_test.shape
# Out:
# (219, 7)

# %%
# Formula for R^2 adjusted: R^2 adj. = (1−(1−R^2)∗(n−1)/(n−p−1))

# Here, n is the rows & p is the columns
n = X_test.shape[0]
p = X_test.shape[1]
r2 = r2_score(y_test, y_pred)

adj_r2 = (1-(1-r2)*(n-1)/(n-p-1))
adj_r2
# Out:
# 0.7918121135765956

# %% [markdown]
# #Final Comparision of the result
#     Train R^2 : 0.777
#     Train Adjusted R^2 : 0.773
#     Test R^2 : 0.798
#     Test Adjusted R^2 : 0.791
# ##The model seems to have predicted pretty well.
